# %% [markdown]
# # Named Entity Recognition (NER)
# The dataset used in this project is sourced from Kaggle (https://www.kaggle.com/datasets/naseralqaydeh/named-entity-recognition-ner-corpus/data?select=ner.csv) and is derived from the Groningen Meaning Bank (GMB) corpus. This dataset is structured to facilitate the training and evaluation of Named Entity Recognition (NER) models. It consists of tokenized text sequences, where each token is labeled with a corresponding entity class.

# %% [markdown]
# ## Required Installation

# %%
# Required libraries from the Requirements.txt
# !pip install -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 3)) (3.2.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.7.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (3.3.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 8)) (4.47.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 9)) (1.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 10)) (2.5.1+cu121)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (2.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from nltk->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2.11.0a2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (0.29.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 8)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 8)) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 8)) (0.4.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 10)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 10)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (3.20.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.45.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 7)) (1.18.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.13.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 2)) (2024.2.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->-r https://raw.githubusercontent.com/Daniel-Rossi-16/NLP_3_NER/main/requirements.txt (line 11)) (0.1.2)

# %% [markdown]
# ## Upload Dataset

# %%
import os

# Clone the GitHub Repository
print("\nCloning the repository...")
# !git clone https://github.com/Daniel-Rossi-16/NLP_3_NER.git

# Navigate to the Cloned Repository
print("\nNavigating to the cloned repository...")
# %cd NLP_3_NER
print(f"Current working directory: {os.getcwd()}")

# List Files in the Repository
print("\nListing files in the repository...")
# !ls

# Display current directory again for verification
print(f"\nYou are now in the directory: {os.path.abspath(os.getcwd())}")
# Out:
# Cloning the repository...
# Cloning into 'NLP_3_NER'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 44 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 4.06 MiB | 4.79 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
#
# Navigating to the cloned repository...
# /kaggle/working/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER
# Current working directory: /kaggle/working/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER
#
# Listing files in the repository...
# LICENSE  NER_Analysis.ipynb  ner.csv  README.md  requirements.txt
#
# You are now in the directory: /kaggle/working/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER/NLP_3_NER

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Load the Dataset into a DataFrame
import pandas as pd

# Load the dataset from the cloned repository
pd.set_option('display.max_colwidth', None)
df = pd.read_csv("ner.csv")

# Display the first few rows
df.head(20)
# Out:
#       Sentence #  \
# 0    Sentence: 1
# 1    Sentence: 2
# 2    Sentence: 3
# 3    Sentence: 4
# 4    Sentence: 5
# 5    Sentence: 6
# 6    Sentence: 7
# 7    Sentence: 8
# 8    Sentence: 9
# 9   Sentence: 10
# 10  Sentence: 11
# 11  Sentence: 12
# 12  Sentence: 13
# 13  Sentence: 14
# 14  Sentence: 15
# 15  Sentence: 16
# 16  Sentence: 17
# 17  Sentence: 18
# 18  Sentence: 19
# 19  Sentence: 20
#
#                                                                                                                                                                                                                                Sentence  \
# 0                                                                                     Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .
# 1                                                                  Families of soldiers killed in the conflict joined the protesters who carried banners with such slogans as " Bush Number One Terrorist " and " Stop the Bombings . "
# 2                                                                                                                                                                  They marched from the Houses of Parliament to a rally in Hyde Park .
# 3                                                                                                                                                Police put the number of marchers at 10,000 while organizers claimed it was 1,00,000 .
# 4                                                                                           The protest comes on the eve of the annual conference of Britain 's ruling Labor Party in the southern English seaside resort of Brighton .
# 5                                                                                        The party is divided over Britain 's participation in the Iraq conflict and the continued deployment of 8,500 British troops in that country .
# 6                                                                                                                        The London march came ahead of anti-war protests today in other cities , including Rome , Paris , and Madrid .
# 7                                                                   The International Atomic Energy Agency is to hold second day of talks in Vienna Wednesday on how to respond to Iran 's resumption of low-level uranium conversion .
# 8                                                                                                                                               Iran this week restarted parts of the conversion process at its Isfahan nuclear plant .
# 9                                                                             Iranian officials say they expect to get access to sealed sensitive parts of the plant Wednesday , after an IAEA surveillance system begins functioning .
# 10                                                                                                                                                                       The step will allow the facility to operate at full capacity .
# 11                             The European Union , with U.S. backing , has threatened to refer Iran to the U.N. Security Council , which could impose sanctions if it finds Tehran has violated the Nuclear Non-Proliferation treaty .
# 12                                                       Iran 's new President Mahmoud Ahmadinejad said Tuesday that European incentives aimed at persuading Iran to end its nuclear fuel program are an insult to the Iranian nation .
# 13                                                                                   Two Germans and four Nigerian oil workers were kidnapped by armed militants during a raid on a boat in Nigeria 's southern oil-rich Delta region .
# 14  An official with the German firm Bilfinger Berger , Thomas Horbach , said the gunmen stopped the supply boat Wednesday as it sailed from Delta State to Bayelsa State to inspect an offshore oil field owned by Royal-Dutch Shell .
# 15                                                                                                                                                                                The German firm works as a sub-contractor for Shell .
# 16                                                                            Militant groups frequently attack oil operations in the Niger Delta to demand social services and better job opportunities from multinational companies .
# 17                                     Poor residents often complain they have been cheated out of the huge riches extracted from their tribal lands - where the bulk of Nigeria 's 2.3 million barrels of petroleum are pumped daily .
# 18                                                                                                        Suspected Islamist rebels have fired mortar shells at the palace used by Somalia 's interim President Abdullahi Yusuf Ahmad .
# 19                                                                                                        It was not immediately clear if the president was in the palace in Mogadishu when the attack occurred or if anyone was hurt .
#
#                                                                                                                                                                                                                                                                POS  \
# 0                                                                                                           ['NNS', 'IN', 'NNS', 'VBP', 'VBN', 'IN', 'NNP', 'TO', 'VB', 'DT', 'NN', 'IN', 'NNP', 'CC', 'VB', 'DT', 'NN', 'IN', 'JJ', 'NNS', 'IN', 'DT', 'NN', '.']
# 1                                                                    ['NNS', 'IN', 'NNS', 'VBN', 'IN', 'DT', 'NN', 'VBD', 'DT', 'NNS', 'WP', 'VBD', 'NNS', 'IN', 'JJ', 'NNS', 'IN', '``', 'NNP', 'NN', 'CD', 'NN', '``', 'CC', '``', 'VB', 'DT', 'NNS', '.', '``']
# 2                                                                                                                                                                         ['PRP', 'VBD', 'IN', 'DT', 'NNS', 'IN', 'NN', 'TO', 'DT', 'NN', 'IN', 'NNP', 'NNP', '.']
# 3                                                                                                                                                                 ['NNS', 'VBD', 'DT', 'NN', 'IN', 'NNS', 'IN', 'CD', 'IN', 'NNS', 'VBD', 'PRP', 'VBD', 'CD', '.']
# 4                                                                                                     ['DT', 'NN', 'VBZ', 'IN', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', 'IN', 'NNP', 'POS', 'VBG', 'NNP', 'NNP', 'IN', 'DT', 'JJ', 'JJ', 'NN', 'NN', 'IN', 'NNP', '.']
# 5                                                                                                            ['DT', 'NN', 'VBZ', 'VBN', 'IN', 'NNP', 'POS', 'NN', 'IN', 'DT', 'NNP', 'NN', 'CC', 'DT', 'JJ', 'NN', 'IN', 'CD', 'JJ', 'NNS', 'IN', 'DT', 'NN', '.']
# 6                                                                                                                               ['DT', 'NNP', 'NN', 'VBD', 'RB', 'IN', 'JJ', 'NNS', 'NN', 'IN', 'JJ', 'NNS', ',', 'VBG', 'NNP', ',', 'NNP', ',', 'CC', 'NNP', '.']
# 7                                                                               ['DT', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'TO', 'VB', 'JJ', 'NN', 'IN', 'NNS', 'IN', 'NNP', 'NNP', 'IN', 'WRB', 'TO', 'VB', 'TO', 'NNP', 'POS', 'NN', 'IN', 'JJ', 'NN', 'NN', '.']
# 8                                                                                                                                                                  ['NNP', 'DT', 'NN', 'VBD', 'NNS', 'IN', 'DT', 'NN', 'NN', 'IN', 'PRP$', 'NNP', 'JJ', 'NN', '.']
# 9                                                                                                    ['JJ', 'NNS', 'VBP', 'PRP', 'VBP', 'TO', 'VB', 'NN', 'TO', 'JJ', 'JJ', 'NNS', 'IN', 'DT', 'NN', 'NNP', ',', 'IN', 'DT', 'NNP', 'NN', 'NN', 'VBZ', 'VBG', '.']
# 10                                                                                                                                                                                         ['DT', 'NN', 'MD', 'VB', 'DT', 'NN', 'TO', 'VB', 'IN', 'JJ', 'NN', '.']
# 11                                      ['DT', 'NNP', 'NNP', ',', 'IN', 'NNP', 'NN', ',', 'VBZ', 'VBN', 'TO', 'VB', 'NNP', 'TO', 'DT', 'NNP', 'NNP', 'NNP', ',', 'WDT', 'MD', 'VB', 'NNS', 'IN', 'PRP', 'VBZ', 'NNP', 'VBZ', 'VBN', 'DT', 'NNP', 'NNP', 'NN', '.']
# 12                                                                     ['NNP', 'POS', 'JJ', 'NNP', 'NNP', 'NNP', 'VBD', 'NNP', 'IN', 'JJ', 'NNS', 'VBN', 'IN', 'VBG', 'NNP', 'TO', 'VB', 'PRP$', 'JJ', 'NN', 'NN', 'VBP', 'DT', 'NN', 'TO', 'DT', 'JJ', 'NN', '.']
# 13                                                                                             ['CD', 'NNS', 'CC', 'CD', 'JJ', 'NN', 'NNS', 'VBD', 'VBN', 'IN', 'JJ', 'NNS', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN', 'IN', 'NNP', 'POS', 'JJ', 'JJ', 'NNP', 'NN', '.']
# 14  ['DT', 'NN', 'IN', 'DT', 'JJ', 'NN', 'NNP', 'NNP', ',', 'NNP', 'NNP', ',', 'VBD', 'DT', 'NNS', 'VBD', 'DT', 'NN', 'NN', 'NNP', 'IN', 'PRP', 'VBD', 'IN', 'NNP', 'NNP', 'TO', 'NNP', 'NNP', 'TO', 'VB', 'DT', 'JJ', 'NN', 'NN', 'VBN', 'IN', 'NNP', 'NNP', '.']
# 15                                                                                                                                                                                                   ['DT', 'JJ', 'NN', 'VBZ', 'IN', 'DT', 'NN', 'IN', 'NNP', '.']
# 16                                                                                                                    ['JJ', 'NNS', 'RB', 'VBP', 'NN', 'NNS', 'IN', 'DT', 'NNP', 'NNP', 'TO', 'VB', 'JJ', 'NNS', 'CC', 'JJR', 'NN', 'NNS', 'IN', 'JJ', 'NNS', '.']
# 17                                     ['JJ', 'NNS', 'RB', 'VBP', 'PRP', 'VBP', 'VBN', 'VBN', 'IN', 'IN', 'DT', 'JJ', 'NNS', 'VBN', 'IN', 'PRP$', 'JJ', 'NNS', ':', 'WRB', 'DT', 'NN', 'IN', 'NNP', 'POS', 'CD', 'CD', 'NNS', 'IN', 'NN', 'VBP', 'VBN', 'RB', '.']
# 18                                                                                                                              ['JJ', 'JJ', 'NNS', 'VBP', 'VBN', 'NN', 'NNS', 'IN', 'DT', 'NN', 'VBN', 'IN', 'NNP', 'POS', 'JJ', 'NNP', 'NNP', 'NNP', 'NNP', '.']
# 19                                                                                                         ['PRP', 'VBD', 'RB', 'RB', 'JJ', 'IN', 'DT', 'NN', 'VBD', 'IN', 'DT', 'NN', 'IN', 'NNP', 'WRB', 'DT', 'NN', 'VBD', 'CC', 'IN', 'DT', 'VBD', 'VBN', '.']
#
#                                                                                                                                                                                                                                                          Tag
# 0                                                                                                                       ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O']
# 1                                                                                                 ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-per', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 2                                                                                                                                                                             ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'I-geo', 'O']
# 3                                                                                                                                                                                ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 4                                                                                                          ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'B-org', 'I-org', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'B-geo', 'O']
# 5                                                                                                                       ['O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O']
# 6                                                                                                                                  ['O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'B-geo', 'O', 'O', 'B-geo', 'O']
# 7                                                                                   ['O', 'B-org', 'I-org', 'I-org', 'I-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'B-tim', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 8                                                                                                                                                                        ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O']
# 9                                                                                                                  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'O', 'O', 'O', 'B-org', 'O', 'O', 'O', 'O', 'O']
# 10                                                                                                                                                                                              ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 11                                        ['O', 'B-org', 'I-org', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'B-org', 'I-org', 'I-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'B-art', 'I-art', 'O', 'O']
# 12                                                                         ['B-gpe', 'O', 'O', 'B-per', 'I-per', 'I-per', 'O', 'B-tim', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O']
# 13                                                                                                        ['O', 'B-gpe', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'B-geo', 'O', 'O']
# 14  ['O', 'O', 'O', 'O', 'B-gpe', 'O', 'B-org', 'I-org', 'O', 'B-per', 'I-per', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'O', 'O', 'O', 'O', 'B-geo', 'I-geo', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-org', 'I-org', 'O']
# 15                                                                                                                                                                                                ['O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'B-org', 'O']
# 16                                                                                                                                    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 17                                                                            ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 18                                                                                                                                  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'B-per', 'I-per', 'I-per', 'I-per', 'O']
# 19                                                                                                                              ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47959 entries, 0 to 47958
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sentence #  47959 non-null  object
#  1   Sentence    47959 non-null  object
#  2   POS         47959 non-null  object
#  3   Tag         47959 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB

# %%
df.isna().sum()
# Out:
# Sentence #    0
# Sentence      0
# POS           0
# Tag           0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
df = pd.read_csv('ner.csv')
#df = df.head(200)

# Shuffle the data
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Split into training (80%), validation (10%), and test (10%)
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Define features (X) and labels (y)
# Combine 'Sentence' and 'POS' as features
X_train = train_df[['Sentence', 'POS']]  # Use both 'Sentence' and 'POS'
y_train = train_df['Tag']  # 'Tag' is the label (NER tags)
X_val = valid_df[['Sentence', 'POS']]
y_val = valid_df['Tag']
X_test = test_df[['Sentence', 'POS']]
y_test = test_df['Tag']

# Check dataset shapes
print(f"Training set size: {train_df.shape}")
print(f"Training set: X={X_train.shape}, y={y_train.shape}")
print(f"\nValidation set size: {valid_df.shape}")
print(f"Validation set: X={X_val.shape}, y={y_val.shape}")
print(f"\nTest set size: {test_df.shape}")
print(f"Test set: X={X_test.shape}, y={y_test.shape}")
# Out:
# Training set size: (38367, 4)
# Training set: X=(38367, 2), y=(38367,)
#
# Validation set size: (4796, 4)
# Validation set: X=(4796, 2), y=(4796,)
#
# Test set size: (4796, 4)
# Test set: X=(4796, 2), y=(4796,)

# %%
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

# 1. Number of samples
num_samples = len(train_df)

# 2. Number of classes (NER tags)
num_classes = train_df['Tag'].nunique()

# 3. Number of samples per class (NER tags)
samples_per_class = train_df['Tag'].value_counts()

# 4. Number of words per sample (calculate the length of each sentence in words)
train_df['word_count'] = train_df['Sentence'].apply(lambda x: len(x.split()))
median_words_per_sample = np.median(train_df['word_count'])
average_words_per_sample = np.mean(train_df['word_count'])

# 5. Frequency distribution of words
all_words = ' '.join(train_df['Sentence']).split()
word_freq = Counter(all_words)
most_common_words = word_freq.most_common(30)
words, counts = zip(*most_common_words)

# 5.1 Plot the frequency distribution
plt.figure(figsize=(10, 6))
plt.barh(words, counts, color='skyblue')
plt.title('Frequency Distribution of Most Common Words in NER Sentences')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.gca().invert_yaxis()  # Invert the y-axis to display the most frequent words at the top
plt.show()

# 6. Distribution of sample length (number of words per sentence)
plt.figure(figsize=(10, 6))
plt.hist(train_df['word_count'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Sample Length (Number of Words per Sentence)')
plt.xlabel('Number of Words per Sentence')
plt.ylabel('Frequency')
plt.show()

# Print the key metrics
print("\nKey Metrics")
print(f"Number of Samples: {num_samples}")
print(f"Number of Classes: {num_classes}")
print(f"Number of Samples per Class:\n{samples_per_class}")
print(f"Median Number of Words per Sentence: {median_words_per_sample}")
print(f"Average Number of Words per Sentence: {average_words_per_sample}")
print(f"Most Common Words and their Frequencies: {most_common_words}")
# Out:
# Key Metrics
# Number of Samples: 38367
# Number of Classes: 27106
# Number of Samples per Class:
# Tag
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                                                                                                                                                   355
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                                                                                                                                    343
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                                                                                                                                         340
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                                                                                                                               325
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                                                                                                                                                        310
#                                                                                                                                                                                                          ...
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-org', 'B-per', 'I-per', 'I-per', 'O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']                                                            1
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-org', 'I-org', 'I-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'B-tim', 'O']                         1
# ['O', 'O', 'O', 'O', 'B-per', 'O', 'O', 'O', 'B-tim', 'O', 'O']                                                                                                                                             1
# ['B-org', 'I-org', 'I-org', 'B-per', 'I-per', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-org', 'O', 'O', 'B-gpe', 'O', 'O']                                1
# ['O', 'B-geo', 'O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'B-geo', 'O', 'O', 'O']      1
# Name: count, Length: 27106, dtype: int64
# Median Number of Words per Sentence: 21.0
# Average Number of Words per Sentence: 21.86126097948758
# Most Common Words and their Frequencies: [('the', 41978), ('.', 38209), (',', 26295), ('in', 21100), ('of', 21051), ('to', 18457), ('a', 16469), ('and', 15908), ('The', 9070), ("'s", 8727), ('for', 6834), ('has', 5849), ('on', 5354), ('is', 5345), ('that', 5041), ('have', 4385), ('said', 4326), ('with', 4281), ('was', 3925), ('says', 3705), ('from', 3653), ('by', 3637), ('at', 3455), ('U.S.', 3306), ('as', 3300), ('say', 3295), ('an', 3108), ('"', 3002), ('are', 2935), ('were', 2833)]

# %%
# 1. Calculate the total number of samples
num_samples = len(train_df)

# 2. Calculate the median number of words per sample
median_words_per_sample = train_df['word_count'].median()

# 3. Calculate the ratio (Number of Samples / Median Number of Words per Sample)
samples_to_median_words_ratio = num_samples / median_words_per_sample

# Print the result
print(f"Number of Samples: {num_samples}")
print(f"Median Number of Words per Sample: {median_words_per_sample}")
print(f"Number of Samples / Median Number of Words per Sample Ratio: {samples_to_median_words_ratio}")
# Out:
# Number of Samples: 38367
# Median Number of Words per Sample: 21.0
# Number of Samples / Median Number of Words per Sample Ratio: 1827.0

# %% [markdown]
# ## Encoding

# %% [markdown]
# Step 1: Flatten the Tags
# The first thing you need to do is flatten the list of tags (since LabelEncoder works on a flat array of labels). For example, if your y_train contains sentences like:
#
# y_train = [['B-per', 'O', 'O'], ['B-org', 'I-org', 'O']]
#
# You need to flatten this list into:
#
# all_tags = ['B-per', 'O', 'O', 'B-org', 'I-org', 'O']

# %%
import pprint

# Pretty-print the first 5 elements of y_train
pp = pprint.PrettyPrinter(width=200, compact=True)
pp.pprint(y_train[:5])
# Out:
# 7707                              ['B-per', 'I-per', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'I-tim', 'O']
# 26089                                                        ['O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 308                                                                         ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'O', 'O']
# 24975                                                                                      ['B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 471      ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'O', 'O', 'B-geo', 'I-geo', 'O', 'B-geo', 'O']
# Name: Tag, dtype: object

# %% [markdown]
# Once you have the flattened list of tags, you can apply the LabelEncoder to fit all unique tags and map them to integer values.
#
# *tag_encoder* knows how to map each unique tag to an integer.

# %%
import ast

# Convert the string representation back to lists
y_train = [ast.literal_eval(tags_str) for tags_str in y_train]
y_val =  [ast.literal_eval(tags_str) for tags_str in y_val]
y_test =  [ast.literal_eval(tags_str) for tags_str in y_test]

# Flatten all tags from y_train, y_val, y_test for fitting the encoder
all_tags   = [tag for sublist in (y_train + y_val + y_test) for tag in sublist]
print(f"All TAG united list: {all_tags [:30]}")
# Out:
# All TAG united list: ['B-per', 'I-per', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'I-tim', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
# Visualize the Distribution of Tags PART 1
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Count the occurrences of each tag
tag_counts = Counter(all_tags)

# Sort the tags by frequency in descending order
sorted_tag_counts = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

# Create separate lists for the sorted tag names and frequencies
sorted_tag_names, sorted_tag_freqs = zip(*sorted_tag_counts)

# Plot the distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=list(sorted_tag_names), y=list(sorted_tag_freqs))
plt.title("Frequency Distribution of NER Tags (Sorted)")
plt.xlabel("NER Tags")
plt.ylabel("Frequency")
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
# Visualize the Distribution of Tags PART 2
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Count the occurrences of each tag
tag_counts = Counter(all_tags)

# Calculate the percentage for each tag
total_tags = len(all_tags)
tag_percentages = {tag: (count / total_tags) * 100 for tag, count in tag_counts.items()}

# Sort tags by frequency in descending order
sorted_tags = sorted(tag_percentages.items(), key=lambda x: x[1], reverse=True)
sorted_tags_names, sorted_tags_percentages = zip(*sorted_tags)

# Plot the distribution with percentages
plt.figure(figsize=(10, 6))
sns.barplot(x=list(sorted_tags_names), y=list(sorted_tags_percentages))
plt.title("Percentage Distribution of NER Tags")
plt.xlabel("NER Tags")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=90)
plt.show()

# Display the sorted tag percentages (optional)
for tag, percentage in zip(sorted_tags_names, sorted_tags_percentages):
    print(f"{tag}: {percentage:.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# O: 84.68%
# B-geo: 3.59%
# B-tim: 1.94%
# B-org: 1.92%
# I-per: 1.65%
# B-per: 1.62%
# I-org: 1.60%
# B-gpe: 1.51%
# I-geo: 0.71%
# I-tim: 0.62%
# B-art: 0.04%
# B-eve: 0.03%
# I-art: 0.03%
# I-eve: 0.02%
# B-nat: 0.02%
# I-gpe: 0.02%
# I-nat: 0.00%

# %% [markdown]
# The `LabelEncoder` was applied only to the NER tags because they are discrete categorical labels, which makes them suitable for this encoding method. On the other hand, the `Sentence` and `POS` columns require tokenization, as they consist of words that need to be converted into numerical representations. Tokenization helps preserve the semantic meaning of the words. Thus, the NER tags are encoded using `LabelEncoder`, while the `Sentence` and `POS` columns are tokenized to generate meaningful word representations for the LSTM model.

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
tag_encoder = LabelEncoder()

# Label encoding for tags
tag_encoder.fit(all_tags)

# Encode tags as numbers
y_train_encoded = [tag_encoder.transform(tag_list) for tag_list in y_train]
y_val_encoded = [tag_encoder.transform(tag_list) for tag_list in y_val]
y_test_encoded = [tag_encoder.transform(tag_list) for tag_list in y_test]


# Tokenization of 'Sentence'
sentence_tokenizer = Tokenizer(oov_token="<OOV>")
sentence_tokenizer.fit_on_texts(X_train['Sentence'])

X_train_sentences = sentence_tokenizer.texts_to_sequences(X_train['Sentence'])
X_val_sentences = sentence_tokenizer.texts_to_sequences(X_val['Sentence'])
X_test_sentences = sentence_tokenizer.texts_to_sequences(X_test['Sentence'])

# Tokenization of 'POS' tags
pos_tokenizer = Tokenizer(oov_token="<OOV>")
pos_tokenizer.fit_on_texts(X_train['POS'])

X_train_pos = pos_tokenizer.texts_to_sequences(X_train['POS'])
X_val_pos = pos_tokenizer.texts_to_sequences(X_val['POS'])
X_test_pos = pos_tokenizer.texts_to_sequences(X_test['POS'])

# Determine maximum sequence length
max_length = max(max(len(seq) for seq in X_train_sentences),
                 max(len(seq) for seq in X_val_sentences),
                 max(len(seq) for seq in X_test_sentences))

# Pad sequences for uniform input length
X_train_padded = pad_sequences(X_train_sentences, maxlen=max_length, padding='post')
X_val_padded = pad_sequences(X_val_sentences, maxlen=max_length, padding='post')
X_test_padded = pad_sequences(X_test_sentences, maxlen=max_length, padding='post')

X_train_pos_padded = pad_sequences(X_train_pos, maxlen=max_length, padding='post')
X_val_pos_padded = pad_sequences(X_val_pos, maxlen=max_length, padding='post')
X_test_pos_padded = pad_sequences(X_test_pos, maxlen=max_length, padding='post')

y_train_padded = pad_sequences(y_train_encoded, maxlen=max_length, padding='post')
y_val_padded = pad_sequences(y_val_encoded, maxlen=max_length, padding='post')
y_test_padded = pad_sequences(y_test_encoded, maxlen=max_length, padding='post')

# Print final dataset shapes
print(f"X_train shape: {X_train_padded.shape}, POS shape: {X_train_pos_padded.shape}, y_train shape: {y_train_padded.shape}")
print(f"X_val shape: {X_val_padded.shape}, POS shape: {X_val_pos_padded.shape}, y_val shape: {y_val_padded.shape}")
print(f"X_test shape: {X_test_padded.shape}, POS shape: {X_test_pos_padded.shape}, y_test shape: {y_test_padded.shape}")
# Out:
# X_train shape: (38367, 89), POS shape: (38367, 89), y_train shape: (38367, 89)
# X_val shape: (4796, 89), POS shape: (4796, 89), y_val shape: (4796, 89)
# X_test shape: (4796, 89), POS shape: (4796, 89), y_test shape: (4796, 89)

# %% [markdown]
# ## Train a Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Bidirectional, Dense, Dropout, Masking
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2


# Define the input shape for both Sentence and POS
sentence_input = Input(shape=(max_length,), dtype=tf.int32, name='sentence_input')
pos_input = Input(shape=(max_length,), dtype=tf.int32, name='pos_input')

# Embedding layers for 'Sentence' and 'POS'
sentence_embedding = Embedding(input_dim=len(sentence_tokenizer.word_index) + 1, 
                               output_dim=128, input_length=max_length)(sentence_input)

pos_embedding = Embedding(input_dim=len(pos_tokenizer.word_index) + 1, 
                          output_dim=64, input_length=max_length)(pos_input)

# Combine both sentence and POS embeddings
merged = tf.keras.layers.concatenate([sentence_embedding, pos_embedding])

# Add a Bidirectional LSTM layer
lstm_out = Bidirectional(LSTM(128, return_sequences=True, dropout=0.4, kernel_regularizer=l2(0.01)))(merged)

# Output layer for NER tag prediction
output = Dense(len(tag_encoder.classes_), activation='softmax')(lstm_out)

# Create the model
model = Model(inputs=[sentence_input, pos_input], outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ sentence_input            │ (None, 89)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pos_input (InputLayer)    │ (None, 89)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_31 (Embedding)  │ (None, 89, 128)        │      3,290,496 │ sentence_input[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_32 (Embedding)  │ (None, 89, 64)         │          2,496 │ pos_input[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_15            │ (None, 89, 192)        │              0 │ embedding_31[0][0],    │
# │ (Concatenate)             │                        │                │ embedding_32[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_13          │ (None, 89, 256)        │        328,704 │ concatenate_15[0][0]   │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 89, 17)         │          4,369 │ bidirectional_13[0][0] │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 3,626,065 (13.83 MB)
#  Trainable params: 3,626,065 (13.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train a Model

# %%
# Train the model

from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)


history = model.fit(
    [X_train_padded, X_train_pos_padded], y_train_padded,
    validation_data=([X_val_padded, X_val_pos_padded], y_val_padded),
    epochs=10, batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.9472 - loss: 0.8320 - val_accuracy: 0.9733 - val_loss: 0.1096
# Epoch 2/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9747 - loss: 0.1202 - val_accuracy: 0.9789 - val_loss: 0.0821
# Epoch 3/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9792 - loss: 0.0836 - val_accuracy: 0.9812 - val_loss: 0.0710
# Epoch 4/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9817 - loss: 0.0810 - val_accuracy: 0.9832 - val_loss: 0.0657
# Epoch 5/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9842 - loss: 0.0613 - val_accuracy: 0.9837 - val_loss: 0.0616
# Epoch 6/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9844 - loss: 0.0682 - val_accuracy: 0.9836 - val_loss: 0.0645
# Epoch 7/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9847 - loss: 0.0597 - val_accuracy: 0.9844 - val_loss: 0.0599
# Epoch 8/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9854 - loss: 0.0593 - val_accuracy: 0.9849 - val_loss: 0.0596
# Epoch 9/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9865 - loss: 0.0521 - val_accuracy: 0.9855 - val_loss: 0.0564
# Epoch 10/10
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9871 - loss: 0.0515 - val_accuracy: 0.9856 - val_loss: 0.0556

# %% [markdown]
# # Evaluation and Conclusion

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(
    [X_test_padded, X_test_pos_padded], y_test_padded
)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9860 - loss: 0.0535
# Test accuracy: 98.60%

# %%
import matplotlib.pyplot as plt

# Extract the training history
history_dict = history.history

# Plot training and validation loss
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history_dict['loss'], label='Training Loss')
plt.plot(history_dict['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history_dict['accuracy'], label='Training Accuracy')
plt.plot(history_dict['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# %%
def plot_predictions(X_test_data, y_test_data, predictions, n=5):
    # Choose n samples randomly
    indices = np.random.choice(len(X_test_data), n, replace=False)
    
    for i in indices:
        # Get the true labels and predicted labels
        true_labels = y_test_data[i]
        predicted_labels = np.argmax(predictions[i], axis=-1)
        
        # Get the length of the true sentence (excluding padding)
        true_length = np.sum(true_labels != 0)  # Assuming 0 is the padding value
        
        # Truncate the predicted labels to match the true sentence length
        predicted_labels = predicted_labels[:true_length]
        
        # Convert the numeric labels back to the original tag names
        true_tags = tag_encoder.inverse_transform(true_labels[:true_length])
        predicted_tags = tag_encoder.inverse_transform(predicted_labels)

        # Print the sentence and tags
        print(f"Sentence: {X_test_data.iloc[i]['Sentence']}")
        print(f"True Tags: {true_tags}")
        print(f"Predicted Tags: {predicted_tags}")
        print("-" * 50)

# Predict using the trained model
predictions = model.predict([X_test_padded, X_test_pos_padded])

# Visualize predictions for 5 random test samples
plot_predictions(X_test, y_test_encoded, predictions, n=5)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Sentence: The opposition National League for Democracy won the last elections in 1990 , but the military government refused to acknowledge the results .
# True Tags: ['O' 'O' 'B-org' 'I-org' 'I-org' 'I-org' 'O' 'O' 'O' 'O' 'O' 'B-tim' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
# Predicted Tags: ['O' 'O' 'B-org' 'I-org' 'I-org' 'I-org' 'O' 'O' 'O' 'O' 'O' 'B-tim' 'O'
#  'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
# --------------------------------------------------
# Sentence: West Indian bowler Dwayne Bravo was Mar-46 and Jerome Taylor was Feb-45 .
# True Tags: ['B-geo' 'B-gpe' 'O' 'B-per' 'I-per' 'O' 'O' 'O' 'B-per' 'I-per' 'O' 'O'
#  'O']
# Predicted Tags: ['B-org' 'B-gpe' 'O' 'B-per' 'I-per' 'O' 'O' 'O' 'B-per' 'I-per' 'O' 'O'
#  'O']
# --------------------------------------------------
# Sentence: There has been no claim of responsibility for the bombings in the mainly Shi'ite southern city of Amarah .
# True Tags: ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-geo' 'O']
# Predicted Tags: ['O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-geo' 'O']
# --------------------------------------------------
# Sentence: Government spokesman Yong Chanthalangsy said Tuesday at least 17 birds have died of the virus in Non-Sawang , a village just outside the capital , Vientiane .
# True Tags: ['O' 'O' 'B-per' 'I-per' 'O' 'B-tim' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'B-geo' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-geo' 'O']
# Predicted Tags: ['B-org' 'O' 'B-per' 'I-per' 'O' 'B-tim' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'O' 'O' 'B-geo' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O']
# --------------------------------------------------
# Sentence: Copper for May delivery settled at $ 1.459 per pound , unchanged from yesterday .
# True Tags: ['O' 'O' 'B-tim' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-tim' 'O']
# Predicted Tags: ['O' 'O' 'B-tim' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-tim']
# --------------------------------------------------
